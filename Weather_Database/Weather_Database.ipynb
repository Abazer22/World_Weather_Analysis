# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from citipy import citipy

from datetime import datetime 
import requests

# Import the API key.
from config import weather_api_key 
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_weather_decription = city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description":city_weather_decription}) 
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Indicate that Data Loading is complete.
# Out:
# Processing Record 1 of Set 15 | luderitz
# Processing Record 2 of Set 15 | wagar
# Processing Record 3 of Set 15 | rikitea
# Processing Record 4 of Set 15 | cape town
# Processing Record 5 of Set 15 | ushuaia
# Processing Record 6 of Set 15 | punta arenas
# Processing Record 7 of Set 15 | port alfred
# Processing Record 8 of Set 15 | khatanga
# Processing Record 9 of Set 15 | razole
# Processing Record 10 of Set 15 | kanganpur
# Processing Record 11 of Set 15 | tuktoyaktuk
# Processing Record 12 of Set 15 | albany
# Processing Record 13 of Set 15 | edd
# Processing Record 14 of Set 15 | maldonado
# Processing Record 15 of Set 15 | altay
# Processing Record 16 of Set 15 | hermanus
# Processing Record 17 of Set 15 | bluff
# Processing Record 18 of Set 15 | savannah bight
# Processing Record 19 of Set 15 | kapaa
# Processing Record 20 of Set 15 | contamana
# Processing Record 21 of Set 15 | berkak
# Processing Record 22 of Set 15 | atuona
# Processing Record 23 of Set 15 | puerto ayora
# Processing Record 24 of Set 15 | pevek
# Processing Record 25 of Set 15 | kyzyl-mazhalyk
# Processing Record 26 of Set 15 | busselton
# Processing Record 27 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 15 | airai
# Processing Record 29 of Set 15 | bambous virieux
# Processing Record 30 of Set 15 | mataura
# Processing Record 31 of Set 15 | nusaybin
# Processing Record 32 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 15 | westport
# Processing Record 34 of Set 15 | port elizabeth
# Processing Record 35 of Set 15 | piacabucu
# Processing Record 36 of Set 15 | sao joao da barra
# Processing Record 37 of Set 15 | colares
# Processing Record 38 of Set 15 | lumut
# Processing Record 39 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 15 | luena
# Processing Record 41 of Set 15 | petropavlovka
# Processing Record 42 of Set 15 | borborema
# Processing Record 43 of Set 15 | qaanaaq
# Processing Record 44 of Set 15 | cidreira
# Processing Record 45 of Set 15 | vaini
# Processing Record 46 of Set 15 | saint-philippe
# Processing Record 47 of Set 15 | misratah
# Processing Record 48 of Set 15 | chuy
# Processing Record 49 of Set 15 | dikson
# Processing Record 50 of Set 15 | castro
# Processing Record 1 of Set 16 | palu
# Processing Record 2 of Set 16 | hilo
# Processing Record 3 of Set 16 | hobart
# Processing Record 4 of Set 16 | tamale
# Processing Record 5 of Set 16 | bereda
# Processing Record 6 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 16 | lebu
# Processing Record 8 of Set 16 | san quintin
# Processing Record 9 of Set 16 | bozhou
# Processing Record 10 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 16 | vanimo
# Processing Record 12 of Set 16 | chokurdakh
# Processing Record 13 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 16 | ugoofaaru
# Processing Record 15 of Set 16 | ismailia
# Processing Record 16 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 16 | tomatlan
# Processing Record 18 of Set 16 | talnakh
# Processing Record 19 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 16 | yellowknife
# Processing Record 21 of Set 16 | hithadhoo
# Processing Record 22 of Set 16 | victoria
# Processing Record 23 of Set 16 | smidovich
# Processing Record 24 of Set 16 | tasiilaq
# Processing Record 25 of Set 16 | lubango
# Processing Record 26 of Set 16 | bethel
# Processing Record 27 of Set 16 | maniitsoq
# Processing Record 28 of Set 16 | kavieng
# Processing Record 29 of Set 16 | lewistown
# Processing Record 30 of Set 16 | bitung
# Processing Record 31 of Set 16 | boende
# Processing Record 32 of Set 16 | esperance
# Processing Record 33 of Set 16 | kloulklubed
# Processing Record 34 of Set 16 | kalmunai
# Processing Record 35 of Set 16 | prince rupert
# Processing Record 36 of Set 16 | haines junction
# Processing Record 37 of Set 16 | saldanha
# Processing Record 38 of Set 16 | sandakan
# Processing Record 39 of Set 16 | lazaro cardenas
# Processing Record 40 of Set 16 | astana
# Processing Record 41 of Set 16 | arraial do cabo
# Processing Record 42 of Set 16 | bafoulabe
# Processing Record 43 of Set 16 | moerai
# Processing Record 44 of Set 16 | pangai
# Processing Record 45 of Set 16 | saint george
# Processing Record 46 of Set 16 | thompson
# Processing Record 47 of Set 16 | bengkulu
# Processing Record 48 of Set 16 | nikki
# Processing Record 49 of Set 16 | norman wells
# Processing Record 50 of Set 16 | coxim
# Processing Record 1 of Set 17 | bredasdorp
# Processing Record 2 of Set 17 | cotacachi
# Processing Record 3 of Set 17 | iqaluit
# Processing Record 4 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 17 | grand-santi
# Processing Record 6 of Set 17 | pangnirtung
# Processing Record 7 of Set 17 | santa ines
# Processing Record 8 of Set 17 | cap malheureux
# Processing Record 9 of Set 17 | paraopeba
# Processing Record 10 of Set 17 | houlung
# City not found. Skipping...
# Processing Record 11 of Set 17 | faanui
# Processing Record 12 of Set 17 | san rafael
# Processing Record 13 of Set 17 | malindi
# Processing Record 14 of Set 17 | borazjan
# Processing Record 15 of Set 17 | pinega
# Processing Record 16 of Set 17 | kununurra
# Processing Record 17 of Set 17 | vestmannaeyjar
# Processing Record 18 of Set 17 | kodiak
# Processing Record 19 of Set 17 | losheim
# Processing Record 20 of Set 17 | tuatapere
# Processing Record 21 of Set 17 | nikolskoye
# Processing Record 22 of Set 17 | hay river
# Processing Record 23 of Set 17 | laguna
# Processing Record 24 of Set 17 | grindavik
# Processing Record 25 of Set 17 | east london
# Processing Record 26 of Set 17 | nanortalik
# Processing Record 27 of Set 17 | matiri
# Processing Record 28 of Set 17 | vila velha
# Processing Record 29 of Set 17 | esik
# Processing Record 30 of Set 17 | provideniya
# Processing Record 31 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 17 | goderich
# Processing Record 33 of Set 17 | georgetown
# Processing Record 34 of Set 17 | kemin
# Processing Record 35 of Set 17 | geraldton
# Processing Record 36 of Set 17 | torbay
# Processing Record 37 of Set 17 | severo-kurilsk
# Processing Record 38 of Set 17 | floro
# Processing Record 39 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 17 | presidente medici
# Processing Record 41 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 17 | zeya
# Processing Record 43 of Set 17 | caravelas
# Processing Record 44 of Set 17 | carnarvon
# Processing Record 45 of Set 17 | arlit
# Processing Record 46 of Set 17 | ancud
# Processing Record 47 of Set 17 | hudson bay
# Processing Record 48 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 17 | belyy yar
# Processing Record 50 of Set 17 | callaway
# Processing Record 1 of Set 18 | korla
# Processing Record 2 of Set 18 | tillabery
# City not found. Skipping...
# Processing Record 3 of Set 18 | new iberia
# Processing Record 4 of Set 18 | solnechnyy
# Processing Record 5 of Set 18 | zyryanka
# Processing Record 6 of Set 18 | boa vista
# Processing Record 7 of Set 18 | sao filipe
# Processing Record 8 of Set 18 | southbridge
# Processing Record 9 of Set 18 | bubaque
# Processing Record 10 of Set 18 | lompoc
# Processing Record 11 of Set 18 | oktyabrskiy
# Processing Record 12 of Set 18 | trelew
# Processing Record 13 of Set 18 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 18 | maceio
# Processing Record 15 of Set 18 | paamiut
# Processing Record 16 of Set 18 | berlare
# Processing Record 17 of Set 18 | upernavik
# Processing Record 18 of Set 18 | tilichiki
# Processing Record 19 of Set 18 | sinnamary
# Processing Record 20 of Set 18 | gzhatsk
# City not found. Skipping...
# Processing Record 21 of Set 18 | ponta do sol
# Processing Record 22 of Set 18 | mount isa
# Processing Record 23 of Set 18 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 18 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 18 | rawson
# Processing Record 26 of Set 18 | mahon
# Processing Record 27 of Set 18 | fukue
# Processing Record 28 of Set 18 | nerchinskiy zavod
# Processing Record 29 of Set 18 | shubarkuduk
# Processing Record 30 of Set 18 | cabo san lucas
# Processing Record 31 of Set 18 | saskylakh
# Processing Record 32 of Set 18 | villa bruzual
# Processing Record 33 of Set 18 | high level
# Processing Record 34 of Set 18 | alekseyevsk
# Processing Record 35 of Set 18 | hofn
# Processing Record 36 of Set 18 | pizarro
# Processing Record 37 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 18 | ortega
# Processing Record 39 of Set 18 | san cristobal
# Processing Record 40 of Set 18 | padang
# Processing Record 41 of Set 18 | nouadhibou
# Processing Record 42 of Set 18 | lipari
# Processing Record 43 of Set 18 | sheregesh
# Processing Record 44 of Set 18 | barrow
# Processing Record 45 of Set 18 | jamestown
# Processing Record 46 of Set 18 | mar del plata
# Processing Record 47 of Set 18 | vallenar
# Processing Record 48 of Set 18 | tagusao
# Processing Record 49 of Set 18 | zyryanovsk
# Processing Record 50 of Set 18 | pimenta bueno
# Processing Record 1 of Set 19 | choix
# Processing Record 2 of Set 19 | mahebourg
# Processing Record 3 of Set 19 | rocha
# Processing Record 4 of Set 19 | san vicente
# Processing Record 5 of Set 19 | avarua
# Processing Record 6 of Set 19 | los llanos de aridane
# Processing Record 7 of Set 19 | kuala krai
# City not found. Skipping...
# Processing Record 8 of Set 19 | rio gallegos
# Processing Record 9 of Set 19 | carlsbad
# Processing Record 10 of Set 19 | launceston
# Processing Record 11 of Set 19 | coahuayana
# Processing Record 12 of Set 19 | ponta delgada
# Processing Record 13 of Set 19 | souillac
# Processing Record 14 of Set 19 | beloha
# Processing Record 15 of Set 19 | belo oriente
# Processing Record 16 of Set 19 | zulpich
# Processing Record 17 of Set 19 | zdvinsk
# Processing Record 18 of Set 19 | shingu
# Processing Record 19 of Set 19 | hagere hiywet
# Processing Record 20 of Set 19 | lingao
# Processing Record 21 of Set 19 | katsuura
# Processing Record 22 of Set 19 | narsaq
# Processing Record 23 of Set 19 | kavaratti
# Processing Record 24 of Set 19 | charleville-mezieres
# Processing Record 25 of Set 19 | suluq
# Processing Record 26 of Set 19 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 19 | poykovskiy
# Processing Record 28 of Set 19 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 19 | merauke
# Processing Record 30 of Set 19 | gamba
# Processing Record 31 of Set 19 | durres
# Processing Record 32 of Set 19 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 19 | ribeira grande
# Processing Record 34 of Set 19 | muros
# Processing Record 35 of Set 19 | hambantota
# Processing Record 36 of Set 19 | faya
# Processing Record 37 of Set 19 | alacranes
# Processing Record 38 of Set 19 | merrill
# Processing Record 39 of Set 19 | belmonte
# Processing Record 40 of Set 19 | skegness
# Processing Record 41 of Set 19 | adrar
# Processing Record 42 of Set 19 | richards bay
# Processing Record 43 of Set 19 | zonguldak
# Processing Record 44 of Set 19 | kirkuk
# Processing Record 45 of Set 19 | new norfolk
# Processing Record 46 of Set 19 | da nang
# Processing Record 47 of Set 19 | nanticoke
# Processing Record 48 of Set 19 | bhiwani
# Processing Record 49 of Set 19 | statesboro
# Processing Record 50 of Set 19 | owando
# Processing Record 1 of Set 20 | sao paulo de olivenca
# Processing Record 2 of Set 20 | guarapari
# Processing Record 3 of Set 20 | codrington
# Processing Record 4 of Set 20 | gold coast
# Processing Record 5 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 20 | katete
# Processing Record 7 of Set 20 | douentza
# Processing Record 8 of Set 20 | qaqortoq
# Processing Record 9 of Set 20 | kondagaon
# Processing Record 10 of Set 20 | mackay
# Processing Record 11 of Set 20 | kruisfontein
# Processing Record 12 of Set 20 | te anau
# Processing Record 13 of Set 20 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 20 | berlevag
# Processing Record 15 of Set 20 | sterling
# Processing Record 16 of Set 20 | verkhoyansk
# Processing Record 17 of Set 20 | aklavik
# Processing Record 18 of Set 20 | ibra
# Processing Record 19 of Set 20 | saysain
# Processing Record 20 of Set 20 | saint-joseph
# Processing Record 21 of Set 20 | beyneu
# Processing Record 22 of Set 20 | mokhsogollokh
# Processing Record 23 of Set 20 | bahia blanca
# Processing Record 24 of Set 20 | manicore
# Processing Record 25 of Set 20 | dharampur
# Processing Record 26 of Set 20 | nurota
# Processing Record 27 of Set 20 | zheleznodorozhnyy
# Processing Record 28 of Set 20 | seondha
# Processing Record 29 of Set 20 | sisimiut
# Processing Record 30 of Set 20 | tual
# Processing Record 31 of Set 20 | adeje
# Processing Record 32 of Set 20 | constitucion
# Processing Record 33 of Set 20 | kenai
# Processing Record 34 of Set 20 | tizimin
# Processing Record 35 of Set 20 | port hawkesbury
# Processing Record 36 of Set 20 | broome
# Processing Record 37 of Set 20 | monrovia
# Processing Record 38 of Set 20 | vera cruz
# Processing Record 39 of Set 20 | vao
# Processing Record 40 of Set 20 | eureka
# Processing Record 41 of Set 20 | ixtapa
# Processing Record 42 of Set 20 | ler
# Processing Record 43 of Set 20 | monte cristi
# City not found. Skipping...
# Processing Record 44 of Set 20 | hobyo
# Processing Record 45 of Set 20 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 20 | kiruna
# Processing Record 47 of Set 20 | lincoln
# Processing Record 48 of Set 20 | thayetmyo
# Processing Record 49 of Set 20 | ngorongoro
# Processing Record 50 of Set 20 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 21 | baruun-urt
# Processing Record 2 of Set 21 | dublin
# Processing Record 3 of Set 21 | victor harbor
# Processing Record 4 of Set 21 | fairbanks
# Processing Record 5 of Set 21 | khash
# Processing Record 6 of Set 21 | manzhouli
# Processing Record 7 of Set 21 | butaritari
# Processing Record 8 of Set 21 | kidal
# Processing Record 9 of Set 21 | panjab
# Processing Record 10 of Set 21 | lamu
# Processing Record 11 of Set 21 | kaitangata
# Processing Record 12 of Set 21 | mount gambier
# Processing Record 13 of Set 21 | bafq
# Processing Record 14 of Set 21 | axim
# Processing Record 15 of Set 21 | pacific grove
# Processing Record 16 of Set 21 | makat
# Processing Record 17 of Set 21 | mareeba
# Processing Record 18 of Set 21 | gat
# Processing Record 19 of Set 21 | chake chake
# Processing Record 20 of Set 21 | awjilah
# Processing Record 21 of Set 21 | tiksi
# Processing Record 22 of Set 21 | namibe
# Processing Record 23 of Set 21 | teknaf
# Processing Record 24 of Set 21 | pemangkat
# Processing Record 25 of Set 21 | zaraza
# Processing Record 26 of Set 21 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 21 | saint anthony
# Processing Record 28 of Set 21 | ko samui
# Processing Record 29 of Set 21 | okato
# Processing Record 30 of Set 21 | ballangen
# Processing Record 31 of Set 21 | dingle
# Processing Record 32 of Set 21 | camopi
# Processing Record 33 of Set 21 | alugan
# Processing Record 34 of Set 21 | tokur
# Processing Record 35 of Set 21 | tromso
# Processing Record 36 of Set 21 | alexander city
# Processing Record 37 of Set 21 | port lincoln
# Processing Record 38 of Set 21 | krasnyy klyuch
# Processing Record 39 of Set 21 | spearfish
# Processing Record 40 of Set 21 | zhangye
# Processing Record 41 of Set 21 | hami
# Processing Record 42 of Set 21 | bogorodskoye
# Processing Record 43 of Set 21 | bloemhof
# Processing Record 44 of Set 21 | chicama
# Processing Record 45 of Set 21 | pietarsaari
# Processing Record 46 of Set 21 | lasa
# Processing Record 47 of Set 21 | karamken
# City not found. Skipping...
# Processing Record 48 of Set 21 | mount darwin
# Processing Record 49 of Set 21 | puerto escondido
# Processing Record 50 of Set 21 | volot
# Processing Record 1 of Set 22 | leningradskiy
# Processing Record 2 of Set 22 | bol
# Processing Record 3 of Set 22 | porto novo
# Processing Record 4 of Set 22 | flinders
# Processing Record 5 of Set 22 | manono
# Processing Record 6 of Set 22 | nagato
# Processing Record 7 of Set 22 | mansa
# Processing Record 8 of Set 22 | sechura
# Processing Record 9 of Set 22 | makasar
# Processing Record 10 of Set 22 | kassala
# Processing Record 11 of Set 22 | mwinilunga
# Processing Record 12 of Set 22 | puerto leguizamo
# Processing Record 13 of Set 22 | san patricio
# Processing Record 14 of Set 22 | magadan
# Processing Record 15 of Set 22 | cabedelo
# Processing Record 16 of Set 22 | carutapera
# Processing Record 17 of Set 22 | tarhunah
# City not found. Skipping...
# Processing Record 18 of Set 22 | camacha
# Processing Record 19 of Set 22 | bangangte
# Processing Record 20 of Set 22 | ojinaga
# Processing Record 21 of Set 22 | lorengau
# Processing Record 22 of Set 22 | havoysund
# Processing Record 23 of Set 22 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 22 | komsomolskiy
# Processing Record 25 of Set 22 | itoman
# Processing Record 26 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 22 | husavik
# Processing Record 28 of Set 22 | messina
# Processing Record 29 of Set 22 | gotsu
# Processing Record 30 of Set 22 | conde
# Processing Record 31 of Set 22 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 22 | tiarei
# Processing Record 33 of Set 22 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 22 | waitati
# Processing Record 35 of Set 22 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 22 | lavrentiya
# Processing Record 37 of Set 22 | loyga
# Processing Record 38 of Set 22 | valdivia
# Processing Record 39 of Set 22 | verkhoshizhemye
# Processing Record 40 of Set 22 | lyangasovo
# Processing Record 41 of Set 22 | prainha
# Processing Record 42 of Set 22 | la rioja
# Processing Record 43 of Set 22 | cam ranh
# Processing Record 44 of Set 22 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 22 | clyde river
# Processing Record 47 of Set 22 | chepen
# Processing Record 48 of Set 22 | maltahohe
# Processing Record 49 of Set 22 | roald
# Processing Record 50 of Set 22 | dubno
# Processing Record 1 of Set 23 | dudinka
# Processing Record 2 of Set 23 | le port
# Processing Record 3 of Set 23 | thinadhoo
# Processing Record 4 of Set 23 | yantal
# Processing Record 5 of Set 23 | fenyi
# Processing Record 6 of Set 23 | tlacotepec
# Processing Record 7 of Set 23 | cape coast
# Processing Record 8 of Set 23 | ostrovnoy
# Processing Record 9 of Set 23 | quebo
# Processing Record 10 of Set 23 | iguai
# Processing Record 11 of Set 23 | turukhansk
# Processing Record 12 of Set 23 | namatanai
# Processing Record 13 of Set 23 | okoneshnikovo
# Processing Record 14 of Set 23 | sitka
# Processing Record 15 of Set 23 | san clemente
# Processing Record 16 of Set 23 | morondava
# Processing Record 17 of Set 23 | kashi
# Processing Record 18 of Set 23 | tezu
# Processing Record 19 of Set 23 | inhambane
# Processing Record 20 of Set 23 | kulu
# Processing Record 21 of Set 23 | alexandria
# Processing Record 22 of Set 23 | igarka
# Processing Record 23 of Set 23 | iwaki
# Processing Record 24 of Set 23 | fortuna
# Processing Record 25 of Set 23 | avera
# Processing Record 26 of Set 23 | buique
# Processing Record 27 of Set 23 | katsiveli
# City not found. Skipping...
# Processing Record 28 of Set 23 | aborlan
# Processing Record 29 of Set 23 | ambon
# Processing Record 30 of Set 23 | asau
# Processing Record 31 of Set 23 | aksarka
# Processing Record 32 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 23 | sambava
# Processing Record 34 of Set 23 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 23 | vila franca do campo
# Processing Record 36 of Set 23 | muroto
# Processing Record 37 of Set 23 | sorland
# Processing Record 38 of Set 23 | guerrero negro
# Processing Record 39 of Set 23 | hasaki
# Processing Record 40 of Set 23 | hovd
# Processing Record 41 of Set 23 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 23 | ilulissat
# Processing Record 43 of Set 23 | cockburn town
# Processing Record 44 of Set 23 | yekepa
# Processing Record 45 of Set 23 | buala
# Processing Record 46 of Set 23 | noumea
# Processing Record 47 of Set 23 | versalles
# Processing Record 48 of Set 23 | banda aceh
# Processing Record 49 of Set 23 | pisco
# Processing Record 50 of Set 23 | anadyr
# Processing Record 1 of Set 24 | necochea
# Processing Record 2 of Set 24 | athens
# Processing Record 3 of Set 24 | horasan
# Processing Record 4 of Set 24 | kualakapuas
# Processing Record 5 of Set 24 | kiama
# Processing Record 6 of Set 24 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 24 | methoni
# Processing Record 8 of Set 24 | sur
# Processing Record 9 of Set 24 | kamaishi
# Processing Record 10 of Set 24 | dyurtyuli
# Processing Record 11 of Set 24 | parabel
# Processing Record 12 of Set 24 | margate
# Processing Record 13 of Set 24 | beringovskiy
# Processing Record 14 of Set 24 | college
# Processing Record 15 of Set 24 | longyearbyen
# Processing Record 16 of Set 24 | port macquarie
# Processing Record 17 of Set 24 | zhangjiakou
# Processing Record 18 of Set 24 | fort-shevchenko
# Processing Record 19 of Set 24 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 24 | langenburg
# Processing Record 21 of Set 24 | shambu
# Processing Record 22 of Set 24 | takoradi
# Processing Record 23 of Set 24 | nome
# Processing Record 24 of Set 24 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 24 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 24 | flin flon
# Processing Record 27 of Set 24 | nueva loja
# Processing Record 28 of Set 24 | arbazh
# Processing Record 29 of Set 24 | bardiyah
# Processing Record 30 of Set 24 | payson
# Processing Record 31 of Set 24 | svetlogorsk
# Processing Record 32 of Set 24 | egvekinot
# Processing Record 33 of Set 24 | baykit
# Processing Record 34 of Set 24 | khani
# Processing Record 35 of Set 24 | cascais
# Processing Record 36 of Set 24 | nabire
# Processing Record 37 of Set 24 | ovalle
# Processing Record 38 of Set 24 | coquimbo
# Processing Record 39 of Set 24 | dawei
# Processing Record 40 of Set 24 | cherskiy
# Processing Record 41 of Set 24 | jalingo
# Processing Record 42 of Set 24 | ternate
# Processing Record 43 of Set 24 | port hedland
# Processing Record 44 of Set 24 | turkistan
# Processing Record 45 of Set 24 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 24 | sicuani
# Processing Record 47 of Set 24 | acarau
# Processing Record 48 of Set 24 | odweyne
# Processing Record 49 of Set 24 | kroya
# Processing Record 50 of Set 24 | bilibino
# Processing Record 1 of Set 25 | shakawe
# Processing Record 2 of Set 25 | ilhabela
# Processing Record 3 of Set 25 | miandrivazo
# Processing Record 4 of Set 25 | la ronge
# Processing Record 5 of Set 25 | bowen
# Processing Record 6 of Set 25 | lata
# Processing Record 7 of Set 25 | bonthe
# Processing Record 8 of Set 25 | leh
# Processing Record 9 of Set 25 | jardim
# Processing Record 10 of Set 25 | valparaiso
# Processing Record 11 of Set 25 | gushikawa
# Processing Record 12 of Set 25 | alterosa
# Processing Record 13 of Set 25 | bad doberan
# Processing Record 14 of Set 25 | fort nelson
# Processing Record 15 of Set 25 | hutang
# Processing Record 16 of Set 25 | seoni
# Processing Record 17 of Set 25 | garden city
# Processing Record 18 of Set 25 | lagoa
# Processing Record 19 of Set 25 | shenjiamen
# Processing Record 20 of Set 25 | hamilton
# Processing Record 21 of Set 25 | vilhena
# Processing Record 22 of Set 25 | stolin
# Processing Record 23 of Set 25 | tadine
# Processing Record 24 of Set 25 | powell
# Processing Record 25 of Set 25 | touros
# Processing Record 26 of Set 25 | santa maria
# Processing Record 27 of Set 25 | dubrajpur
# Processing Record 28 of Set 25 | manggar
# Processing Record 29 of Set 25 | ormara
# Processing Record 30 of Set 25 | muravlenko
# Processing Record 31 of Set 25 | amapa
# Processing Record 32 of Set 25 | fasa
# Processing Record 33 of Set 25 | san policarpo
# Processing Record 34 of Set 25 | logatec
# Processing Record 35 of Set 25 | omboue
# Processing Record 36 of Set 25 | kunya
# Processing Record 37 of Set 25 | bodden town
# Processing Record 38 of Set 25 | jatai
# Processing Record 39 of Set 25 | pavlovsk
# Processing Record 40 of Set 25 | saint-francois
# Processing Record 41 of Set 25 | tectitan
# City not found. Skipping...
# Processing Record 42 of Set 25 | livingston
# Processing Record 43 of Set 25 | kjopsvik
# Processing Record 44 of Set 25 | dover
# Processing Record 45 of Set 25 | jumla
# Processing Record 46 of Set 25 | zastron
# Processing Record 47 of Set 25 | waddan
# Processing Record 48 of Set 25 | hohhot
# Processing Record 49 of Set 25 | malgrat de mar
# Processing Record 50 of Set 25 | kurchum
# Processing Record 1 of Set 26 | kilemary
# Processing Record 2 of Set 26 | vila
# Processing Record 3 of Set 26 | ust-tarka
# Processing Record 4 of Set 26 | bay roberts
# Processing Record 5 of Set 26 | filingue
# Processing Record 6 of Set 26 | muisne
# Processing Record 7 of Set 26 | ayan
# Processing Record 8 of Set 26 | shihezi
# Processing Record 9 of Set 26 | zlobin
# Processing Record 10 of Set 26 | ende
# Processing Record 11 of Set 26 | alofi
# Processing Record 12 of Set 26 | ushtobe
# Processing Record 13 of Set 26 | vardo
# Processing Record 14 of Set 26 | belle fourche
# Processing Record 15 of Set 26 | ballina
# Processing Record 16 of Set 26 | waingapu
# Processing Record 17 of Set 26 | kristiansand
# Processing Record 18 of Set 26 | arcata
# Processing Record 19 of Set 26 | karratha
# Processing Record 20 of Set 26 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 26 | coihaique
# Processing Record 22 of Set 26 | bolshevik
# Processing Record 23 of Set 26 | araouane
# Processing Record 24 of Set 26 | bathsheba
# Processing Record 25 of Set 26 | kaeo
# Processing Record 26 of Set 26 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 26 | benguela
# Processing Record 28 of Set 26 | kupino
# Processing Record 29 of Set 26 | owase
# Processing Record 30 of Set 26 | mancio lima
# Processing Record 31 of Set 26 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 26 | otane
# Processing Record 33 of Set 26 | komarovo
# Processing Record 34 of Set 26 | burnie
# Processing Record 35 of Set 26 | santander
# Processing Record 36 of Set 26 | podujevo
# Processing Record 37 of Set 26 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 26 | lake charles
# Processing Record 39 of Set 26 | brotas
# Processing Record 40 of Set 26 | gornyy
# Processing Record 41 of Set 26 | ust-kuyga
# Processing Record 42 of Set 26 | martapura
# Processing Record 43 of Set 26 | kyaukse
# Processing Record 44 of Set 26 | grand gaube
# Processing Record 45 of Set 26 | villa constitucion
# Processing Record 46 of Set 26 | albion
# Processing Record 47 of Set 26 | vrangel
# Processing Record 48 of Set 26 | sungaipenuh
# Processing Record 49 of Set 26 | comodoro rivadavia
# Processing Record 50 of Set 26 | batticaloa
# Processing Record 1 of Set 27 | juneau
# Processing Record 2 of Set 27 | japura
# Processing Record 3 of Set 27 | anchorage
# Processing Record 4 of Set 27 | santa rosa
# Processing Record 5 of Set 27 | mazagao
# Processing Record 6 of Set 27 | nemuro
# Processing Record 7 of Set 27 | quatre cocos
# Processing Record 8 of Set 27 | marihatag
# Processing Record 9 of Set 27 | buariki
# City not found. Skipping...
# Processing Record 10 of Set 27 | abu samrah
# Processing Record 11 of Set 27 | micco
# Processing Record 12 of Set 27 | berdigestyakh
# Processing Record 13 of Set 27 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 27 | chitungwiza
# Processing Record 15 of Set 27 | mandalgovi
# Processing Record 16 of Set 27 | litovko
# Processing Record 17 of Set 27 | tura
# Processing Record 18 of Set 27 | tigil
# Processing Record 19 of Set 27 | bintulu
# Processing Record 20 of Set 27 | portland
# Processing Record 21 of Set 27 | navahrudak
# Processing Record 22 of Set 27 | wattegama
# Processing Record 23 of Set 27 | birin
# Processing Record 24 of Set 27 | jasdan
# Processing Record 25 of Set 27 | bumbuna
# Processing Record 26 of Set 27 | novikovo
# Processing Record 27 of Set 27 | puerto narino
# Processing Record 28 of Set 27 | liverpool
# Processing Record 29 of Set 27 | jomalig
# City not found. Skipping...
# Processing Record 30 of Set 27 | houma
# Processing Record 31 of Set 27 | ambilobe
# Processing Record 32 of Set 27 | tocache
# Processing Record 33 of Set 27 | itarema
# Processing Record 34 of Set 27 | nyzhni sirohozy
# Processing Record 35 of Set 27 | ahipara
# Processing Record 36 of Set 27 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 27 | kaohsiung
# Processing Record 38 of Set 27 | mtambile
# Processing Record 39 of Set 27 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 27 | minudasht
# Processing Record 41 of Set 27 | gurdaha
# Processing Record 42 of Set 27 | kerema
# Processing Record 43 of Set 27 | pareora
# Processing Record 44 of Set 27 | zaysan
# Processing Record 45 of Set 27 | henties bay
# Processing Record 46 of Set 27 | consett
# Processing Record 47 of Set 27 | natal
# Processing Record 48 of Set 27 | mitu
# Processing Record 49 of Set 27 | puerto del rosario
# Processing Record 50 of Set 27 | marsabit
# Processing Record 1 of Set 28 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 28 | bandarbeyla
# Processing Record 3 of Set 28 | kerman
# Processing Record 4 of Set 28 | poyarkovo
# Processing Record 5 of Set 28 | tondano
# Processing Record 6 of Set 28 | henderson
# Processing Record 7 of Set 28 | neryungri
# Processing Record 8 of Set 28 | nileshwar
# Processing Record 9 of Set 28 | bukachacha
# Processing Record 10 of Set 28 | magna
# Processing Record 11 of Set 28 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 28 | zhezkazgan
# Processing Record 13 of Set 28 | cadiz
# Processing Record 14 of Set 28 | ust-nera
# Processing Record 15 of Set 28 | auburn
# Processing Record 16 of Set 28 | san angelo
# Processing Record 17 of Set 28 | morant bay
# Processing Record 18 of Set 28 | sept-iles
# Processing Record 19 of Set 28 | uarini
# Processing Record 20 of Set 28 | santa cruz de la palma
# Processing Record 21 of Set 28 | ban chang
# Processing Record 22 of Set 28 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 28 | nishihara
# Processing Record 24 of Set 28 | hollins
# Processing Record 25 of Set 28 | baryatino
# Processing Record 26 of Set 28 | bialogard
# Processing Record 27 of Set 28 | russell
# Processing Record 28 of Set 28 | mudanjiang
# Processing Record 29 of Set 28 | isangel
# Processing Record 30 of Set 28 | broken hill
# Processing Record 31 of Set 28 | zachagansk
# City not found. Skipping...
# Processing Record 32 of Set 28 | dawlatabad
# Processing Record 33 of Set 28 | rio grande
# Processing Record 34 of Set 28 | kathu
# Processing Record 35 of Set 28 | ocampo
# Processing Record 36 of Set 28 | palmer
# Processing Record 37 of Set 28 | kumo
# Processing Record 38 of Set 28 | opobo
# City not found. Skipping...
# Processing Record 39 of Set 28 | elizabeth city
# Processing Record 40 of Set 28 | gizo
# Processing Record 41 of Set 28 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 28 | svarstad
# Processing Record 43 of Set 28 | indramayu
# Processing Record 44 of Set 28 | liwale
# Processing Record 45 of Set 28 | taltal
# Processing Record 46 of Set 28 | qena
# Processing Record 47 of Set 28 | okha
# Processing Record 48 of Set 28 | nanchang
# Processing Record 49 of Set 28 | fare
# Processing Record 50 of Set 28 | codajas
# Processing Record 1 of Set 29 | denpasar
# Processing Record 2 of Set 29 | maroantsetra
# Processing Record 3 of Set 29 | chapais
# Processing Record 4 of Set 29 | sao miguel do araguaia
# Processing Record 5 of Set 29 | cabra
# Processing Record 6 of Set 29 | yangcun
# Processing Record 7 of Set 29 | hualmay
# Processing Record 8 of Set 29 | griffith
# Processing Record 9 of Set 29 | yulara
# Processing Record 10 of Set 29 | santiago del estero
# Processing Record 11 of Set 29 | marsh harbour
# Processing Record 12 of Set 29 | zhigansk
# Processing Record 13 of Set 29 | baturaja
# Processing Record 14 of Set 29 | eirunepe
# Processing Record 15 of Set 29 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 29 | marystown
# Processing Record 17 of Set 29 | derzhavinsk
# Processing Record 18 of Set 29 | amarante do maranhao
# Processing Record 19 of Set 29 | lutz
# Processing Record 20 of Set 29 | plouzane
# Processing Record 21 of Set 29 | sakakah
# Processing Record 22 of Set 29 | kamenka
# Processing Record 23 of Set 29 | daru
# Processing Record 24 of Set 29 | el reno
# Processing Record 25 of Set 29 | santa isabel
# Processing Record 26 of Set 29 | tamandare
# Processing Record 27 of Set 29 | vila do maio
# Processing Record 28 of Set 29 | moscow
# Processing Record 29 of Set 29 | las vegas
# Processing Record 30 of Set 29 | shatrovo
# Processing Record 31 of Set 29 | waipawa
# Processing Record 32 of Set 29 | soyo
# Processing Record 33 of Set 29 | saint-leu
# Processing Record 34 of Set 29 | odesskoye
# Processing Record 35 of Set 29 | ndele
# Processing Record 36 of Set 29 | deputatskiy
# Processing Record 37 of Set 29 | santa lucia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 74.48,
#   'Humidity': 24,
#   'Cloudiness': 100,
#   'Wind Speed': 17.05,
#   'Country': 'NA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Wagar',
#   'Lat': 16.1525,
#   'Lng': 36.2032,
#   'Max Temp': 89.24,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 12.33,
#   'Country': 'SD',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.13,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 18.39,
#   'Country': 'PF',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.12,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 55.02,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 31.07,
#   'Country': 'AR',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 55.51,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 29.93,
#   'Country': 'CL',
#   'Weather Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 57.43,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 29.89,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.37,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Razole',
#   'Lat': 16.4833,
#   'Lng': 81.8333,
#   'Max Temp': 78.57,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'IN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kanganpur',
#   'Lat': 30.7663,
#   'Lng': 74.1231,
#   'Max Temp': 72.88,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.5,
#   'Country': 'PK',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 21.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 53.17,
#   'Humidity': 70,
#   'Cloudiness': 74,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Edd',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 87.62,
#   'Humidity': 66,
#   'Cloudiness': 12,
#   'Wind Speed': 4.52,
#   'Country': 'ER',
#   'Weather Description': 'few clouds'},
#  {'City': 'Maldonado',
#   'Lat': -34.6667,
#   'Lng': -54.9167,
#   'Max Temp': 61.23,
#   'Humidity': 61,
#   'Cloudiness': 25,
#   'Wind Speed': 9.73,
#   'Country': 'UY',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 38.7,
#   'Humidity': 46,
#   'Cloudiness': 18,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 59.9,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.03,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 45.57,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.99,
#   'Country': 'NZ',
#   'Weather Description': 'light rain'},
#  {'City': 'Savannah Bight',
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 86.05,
#   'Humidity': 73,
#   'Cloudiness': 78,
#   'Wind Speed': 6.42,
#   'Country': 'HN',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 78.48,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Weather Description': 'light rain'},
#  {'City': 'Contamana',
#   'Lat': -7.3333,
#   'Lng': -75.0167,
#   'Max Temp': 93.06,
#   'Humidity': 40,
#   'Cloudiness': 84,
#   'Wind Speed': 3.27,
#   'Country': 'PE',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Berkak',
#   'Lat': 62.825,
#   'Lng': 10.0118,
#   'Max Temp': 32.43,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'NO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.92,
#   'Humidity': 76,
#   'Cloudiness': 62,
#   'Wind Speed': 21.21,
#   'Country': 'PF',
#   'Weather Description': 'light rain'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 80,
#   'Cloudiness': 79,
#   'Wind Speed': 9.89,
#   'Country': 'EC',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 7.59,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kyzyl-Mazhalyk',
#   'Lat': 51.1333,
#   'Lng': 90.6,
#   'Max Temp': 32.67,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 59.04,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'AU',
#   'Weather Description': 'light rain'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 62.64,
#   'Humidity': 88,
#   'Cloudiness': 54,
#   'Wind Speed': 1.41,
#   'Country': 'TL',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 74.21,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 43.65,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'NZ',
#   'Weather Description': 'light rain'},
#  {'City': 'Nusaybin',
#   'Lat': 37.0778,
#   'Lng': 41.2178,
#   'Max Temp': 69.39,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'TR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 61.02,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 55.69,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'ZA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Piacabucu',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 81,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 11.25,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 75.29,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 11.3,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Colares',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 75.45,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'PT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lumut',
#   'Lat': 4.2323,
#   'Lng': 100.6298,
#   'Max Temp': 80.96,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Luena',
#   'Lat': -11.7833,
#   'Lng': 19.9167,
#   'Max Temp': 67.05,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'AO',
#   'Weather Description': 'light rain'},
#  {'City': 'Petropavlovka',
#   'Lat': 50.6114,
#   'Lng': 105.3196,
#   'Max Temp': 25.5,
#   'Humidity': 90,
#   'Cloudiness': 11,
#   'Wind Speed': 2.8,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Borborema',
#   'Lat': -21.6197,
#   'Lng': -49.0736,
#   'Max Temp': 77.43,
#   'Humidity': 66,
#   'Cloudiness': 55,
#   'Wind Speed': 10.96,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 27.32,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.65,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 64,
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 8.72,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.56,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'TO',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 72.95,
#   'Humidity': 81,
#   'Cloudiness': 42,
#   'Wind Speed': 15.39,
#   'Country': 'RE',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Misratah',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 73.6,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Country': 'LY',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 62.67,
#   'Humidity': 73,
#   'Cloudiness': 44,
#   'Wind Speed': 8.1,
#   'Country': 'UY',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 31.26,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.15,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 57.97,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Palu',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 75.43,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.71,
#   'Country': 'ID',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 77.61,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 48.06,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tamale',
#   'Lat': 9.4008,
#   'Lng': -0.8393,
#   'Max Temp': 79.81,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 7.34,
#   'Country': 'GH',
#   'Weather Description': 'light rain'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 64.15,
#   'Humidity': 74,
#   'Cloudiness': 95,
#   'Wind Speed': 1.05,
#   'Country': 'ES',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 56.84,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 18.79,
#   'Country': 'CL',
#   'Weather Description': 'clear sky'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 67.48,
#   'Humidity': 60,
#   'Cloudiness': 48,
#   'Wind Speed': 13.02,
#   'Country': 'MX',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bozhou',
#   'Lat': 33.8772,
#   'Lng': 115.7703,
#   'Max Temp': 53.29,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 78.04,
#   'Humidity': 89,
#   'Cloudiness': 66,
#   'Wind Speed': 5.95,
#   'Country': 'PG',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -14.19,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 4.83,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 82.51,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 13.98,
#   'Country': 'MV',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ismailia',
#   'Lat': 30.6043,
#   'Lng': 32.2723,
#   'Max Temp': 69.76,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.16,
#   'Country': 'EG',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 89.2,
#   'Humidity': 62,
#   'Cloudiness': 2,
#   'Wind Speed': 5.77,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 34.41,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 15.9,
#   'Country': 'RU',
#   'Weather Description': 'light rain'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 34.41,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.97,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.7,
#   'Country': 'MV',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 77.32,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Weather Description': 'light rain'},
#  {'City': 'Smidovich',
#   'Lat': 48.6,
#   'Lng': 133.8167,
#   'Max Temp': 24.85,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 7.07,
#   'Country': 'RU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 24.28,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lubango',
#   'Lat': -14.9172,
#   'Lng': 13.4925,
#   'Max Temp': 64.26,
#   'Humidity': 43,
#   'Cloudiness': 4,
#   'Wind Speed': 5.19,
#   'Country': 'AO',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 57.88,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'light rain'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 33.4,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.88,
#   'Country': 'GL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.44,
#   'Humidity': 77,
#   'Cloudiness': 15,
#   'Wind Speed': 13.31,
#   'Country': 'PG',
#   'Weather Description': 'few clouds'},
#  {'City': 'Lewistown',
#   'Lat': 40.5992,
#   'Lng': -77.5714,
#   'Max Temp': 62.42,
#   'Humidity': 53,
#   'Cloudiness': 55,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bitung',
#   'Lat': 1.4451,
#   'Lng': 125.1824,
#   'Max Temp': 77.85,
#   'Humidity': 79,
#   'Cloudiness': 83,
#   'Wind Speed': 4.9,
#   'Country': 'ID',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Boende',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 71.65,
#   'Humidity': 97,
#   'Cloudiness': 84,
#   'Wind Speed': 1.83,
#   'Country': 'CD',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 58.84,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 83.7,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.73,
#   'Country': 'PW',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 81.07,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 1.19,
#   'Country': 'LK',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 46.09,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 19.35,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 59.05,
#   'Humidity': 74,
#   'Cloudiness': 3,
#   'Wind Speed': 20.38,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sandakan',
#   'Lat': 5.8402,
#   'Lng': 118.1179,
#   'Max Temp': 80.28,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'MY',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 85.14,
#   'Humidity': 70,
#   'Cloudiness': 81,
#   'Wind Speed': 4.83,
#   'Country': 'MX',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Astana',
#   'Lat': 51.1801,
#   'Lng': 71.446,
#   'Max Temp': 30.15,
#   'Humidity': 80,
#   'Cloudiness': 21,
#   'Wind Speed': 6.71,
#   'Country': 'KZ',
#   'Weather Description': 'mist'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.26,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bafoulabe',
#   'Lat': 13.8065,
#   'Lng': -10.8321,
#   'Max Temp': 87.69,
#   'Humidity': 34,
#   'Cloudiness': 2,
#   'Wind Speed': 3.91,
#   'Country': 'ML',
#   'Weather Description': 'clear sky'},
#  {'City': 'Moerai',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp': 76.86,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.57,
#   'Country': 'PF',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 77.11,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'TO',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 72.07,
#   'Humidity': 24,
#   'Cloudiness': 20,
#   'Wind Speed': 13,
#   'Country': 'US',
#   'Weather Description': 'few clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 51.96,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 73.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'ID',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Nikki',
#   'Lat': 9.9401,
#   'Lng': 3.2108,
#   'Max Temp': 74.59,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'BJ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 23.04,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Coxim',
#   'Lat': -18.5067,
#   'Lng': -54.76,
#   'Max Temp': 89.91,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 53.28,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cotacachi',
#   'Lat': 0.3,
#   'Lng': -78.2667,
#   'Max Temp': 72.95,
#   'Humidity': 62,
#   'Cloudiness': 88,
#   'Wind Speed': 3.04,
#   'Country': 'EC',
#   'Weather Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 35.33,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 18.01,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Grand-Santi',
#   'Lat': 4.25,
#   'Lng': -54.3833,
#   'Max Temp': 85.73,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'GF',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 33.8,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Santa Ines',
#   'Lat': -3.6667,
#   'Lng': -45.38,
#   'Max Temp': 82.15,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 74.46,
#   'Humidity': 78,
#   'Cloudiness': 56,
#   'Wind Speed': 5.01,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Paraopeba',
#   'Lat': -19.2757,
#   'Lng': -44.4033,
#   'Max Temp': 81.95,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 79.81,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 15.41,
#   'Country': 'PF',
#   'Weather Description': 'light rain'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 76.78,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 14.85,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Malindi',
#   'Lat': -3.2175,
#   'Lng': 40.1191,
#   'Max Temp': 78.96,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'KE',
#   'Weather Description': 'few clouds'},
#  {'City': 'Borazjan',
#   'Lat': 29.2666,
#   'Lng': 51.2159,
#   'Max Temp': 85.33,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'IR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Pinega',
#   'Lat': 64.7001,
#   'Lng': 43.3936,
#   'Max Temp': 35.13,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 76.98,
#   'Humidity': 65,
#   'Cloudiness': 27,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 50.99,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 25.32,
#   'Country': 'IS',
#   'Weather Description': 'light rain'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 45.91,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Weather Description': 'light rain'},
#  {'City': 'Losheim',
#   'Lat': 49.5167,
#   'Lng': 6.75,
#   'Max Temp': 51.1,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'DE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 45.45,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.57,
#   'Country': 'NZ',
#   'Weather Description': 'light rain'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 39.09,
#   'Humidity': 93,
#   'Cloudiness': 12,
#   'Wind Speed': 6.02,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 31.98,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 63.45,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 48.15,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 26.46,
#   'Country': 'IS',
#   'Weather Description': 'moderate rain'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 54.54,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 32.38,
#   'Humidity': 73,
#   'Cloudiness': 41,
#   'Wind Speed': 16.96,
#   'Country': 'GL',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Matiri',
#   'Lat': -10.75,
#   'Lng': 34.9,
#   'Max Temp': 70,
#   'Humidity': 54,
#   'Cloudiness': 61,
#   'Wind Speed': 6.33,
#   'Country': 'TZ',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 75.15,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Esik',
#   'Lat': 43.3552,
#   'Lng': 77.4525,
#   'Max Temp': 40.42,
#   'Humidity': 36,
#   'Cloudiness': 48,
#   'Wind Speed': 5.41,
#   'Country': 'KZ',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 28.06,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 27.11,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 53.92,
#   'Humidity': 54,
#   'Cloudiness': 5,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.89,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kemin',
#   'Lat': 42.7846,
#   'Lng': 75.6892,
#   'Max Temp': 51.73,
#   'Humidity': 45,
#   'Cloudiness': 73,
#   'Wind Speed': 3.18,
#   'Country': 'KG',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 72.01,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Country': 'AU',
#   'Weather Description': 'light intensity shower rain'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 46.27,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'CA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 37.99,
#   'Humidity': 72,
#   'Cloudiness': 88,
#   'Wind Speed': 20.24,
#   'Country': 'RU',
#   'Weather Description': 'light rain'},
#  {'City': 'Floro',
#   'Lat': 61.5996,
#   'Lng': 5.0328,
#   'Max Temp': 46.36,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'NO',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Presidente Medici',
#   'Lat': -11.1753,
#   'Lng': -61.9014,
#   'Max Temp': 75.9,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'BR',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 21.49,
#   'Humidity': 57,
#   'Cloudiness': 29,
#   'Wind Speed': 1.5,
#   'Country': 'RU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 79.95,
#   'Humidity': 70,
#   'Cloudiness': 22,
#   'Wind Speed': 10.47,
#   'Country': 'BR',
#   'Weather Description': 'few clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 75.27,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 28.77,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 89.42,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Country': 'NE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 62.13,
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 7.7,
#   'Country': 'CL',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hudson Bay',
#   'Lat': 52.85,
#   'Lng': -102.3842,
#   'Max Temp': 59.23,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 10.42,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 22.89,
#   'Humidity': 93,
#   'Cloudiness': 18,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Weather Description': 'mist'},
#  {'City': 'Callaway',
#   'Lat': 30.153,
#   'Lng': -85.5699,
#   'Max Temp': 74.91,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 54.14,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'New Iberia',
#   'Lat': 30.0035,
#   'Lng': -91.8187,
#   'Max Temp': 74.05,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 19.49,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.29,
#   'Country': 'RU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 4.66,
#   'Humidity': 91,
#   'Cloudiness': 87,
#   'Wind Speed': 9.6,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 89.58,
#   'Humidity': 45,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 80.31,
#   'Humidity': 73,
#   'Cloudiness': 6,
#   'Wind Speed': 6.98,
#   'Country': 'CV',
#   'Weather Description': 'clear sky'},
#  {'City': 'Southbridge',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 60.3,
#   'Humidity': 58,
#   'Cloudiness': 95,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 83.41,
#   'Humidity': 71,
#   'Cloudiness': 38,
#   'Wind Speed': 8.3,
#   'Country': 'GW',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 71.02,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Oktyabrskiy',
#   'Lat': 54.4815,
#   'Lng': 53.471,
#   'Max Temp': 51.03,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Trelew',
#   'Lat': -43.249,
#   'Lng': -65.3051,
#   'Max Temp': 78.87,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 17.85,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 87.24,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 34.7,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 9.46,
#   'Country': 'GL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Berlare',
#   'Lat': 51.0364,
#   'Lng': 3.9817,
#   'Max Temp': 60.04,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 12.95,
#   'Country': 'BE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 27.54,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 17.02,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 10.11,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 83.07,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Country': 'GF',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 74.12,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 2.98,
#   'Country': 'PT',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 71.37,
#   'Humidity': 49,
#   'Cloudiness': 53,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Weather Description': 'light rain'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 74.19,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 15.5,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mahon',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 66.76,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Fukue',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 65.84,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 14.65,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nerchinskiy Zavod',
#   'Lat': 51.3088,
#   'Lng': 119.61,
#   'Max Temp': 12.92,
#   'Humidity': 95,
#   'Cloudiness': 16,
#   'Wind Speed': 4.29,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Shubarkuduk',
#   'Lat': 49.1447,
#   'Lng': 56.4872,
#   'Max Temp': 51.58,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'KZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 91.62,
#   'Humidity': 65,
#   'Cloudiness': 15,
#   'Wind Speed': 13.71,
#   'Country': 'MX',
#   'Weather Description': 'few clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 24.76,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Villa Bruzual',
#   'Lat': 9.3328,
#   'Lng': -69.1208,
#   'Max Temp': 89.08,
#   'Humidity': 56,
#   'Cloudiness': 72,
#   'Wind Speed': 3.74,
#   'Country': 'VE',
#   'Weather Description': 'broken clouds'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': 32.11,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Alekseyevsk',
#   'Lat': 57.8406,
#   'Lng': 108.3492,
#   'Max Temp': 27.18,
#   'Humidity': 78,
#   'Cloudiness': 73,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 48.22,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'IS',
#   'Weather Description': 'drizzle rain'},
#  {'City': 'Pizarro',
#   'Lat': 4.9533,
#   'Lng': -77.366,
#   'Max Temp': 81.54,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 8.05,
#   'Country': 'CO',
#   'Weather Description': 'light rain'},
#  {'City': 'Ortega',
#   'Lat': 3.9361,
#   'Lng': -75.2217,
#   'Max Temp': 89.51,
#   'Humidity': 51,
#   'Cloudiness': 74,
#   'Wind Speed': 4,
#   'Country': 'CO',
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 82.58,
#   'Humidity': 47,
#   'Cloudiness': 36,
#   'Wind Speed': 8.05,
#   'Country': 'VE',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 75.25,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'ID',
#   'Weather Description': 'light rain'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 80.58,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'MR',
#   'Weather Description': 'few clouds'},
#  {'City': 'Lipari',
#   'Lat': 38.4674,
#   'Lng': 14.954,
#   'Max Temp': 66.78,
#   'Humidity': 63,
#   'Cloudiness': 6,
#   'Wind Speed': 5.93,
#   'Country': 'IT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sheregesh',
#   'Lat': 52.9209,
#   'Lng': 87.9869,
#   'Max Temp': 33.37,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 1.63,
#   'Country': 'RU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 15.82,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 56.52,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 59.02,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 81.93,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 8.88,
#   'Country': 'CL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tagusao',
#   'Lat': 9.1924,
#   'Lng': 117.8141,
#   'Max Temp': 79.38,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 1.7,
#   'Country': 'PH',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zyryanovsk',
#   'Lat': 49.7386,
#   'Lng': 84.2719,
#   'Max Temp': 36.9,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.71,
#   'Country': 'KZ',
#   'Weather Description': 'clear sky'},
#  {'City': 'Pimenta Bueno',
#   'Lat': -11.6725,
#   'Lng': -61.1936,
#   'Max Temp': 73.87,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'BR',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Choix',
#   'Lat': 26.7092,
#   'Lng': -108.3219,
#   'Max Temp': 85.59,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'MX',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 74.25,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 60.78,
#   'Humidity': 73,
#   'Cloudiness': 34,
#   'Wind Speed': 10.22,
#   'Country': 'UY',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'San Vicente',
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp': 74.89,
#   'Humidity': 43,
#   'Cloudiness': 21,
#   'Wind Speed': 6.78,
#   'Country': 'AR',
#   'Weather Description': 'few clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CK',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 78.55,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 66.25,
#   'Humidity': 18,
#   'Cloudiness': 20,
#   'Wind Speed': 34.52,
#   'Country': 'AR',
#   'Weather Description': 'few clouds'},
#  {'City': 'Carlsbad',
#   'Lat': 33.1581,
#   'Lng': -117.3506,
#   'Max Temp': 68.97,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 46.8,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 8.99,
#   'Country': 'AU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 91.44,
#   'Humidity': 55,
#   'Cloudiness': 3,
#   'Wind Speed': 5.32,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.32,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Weather Description': 'few clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 74.35,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 70.74,
#   'Humidity': 86,
#   'Cloudiness': 18,
#   'Wind Speed': 8.52,
#   'Country': 'MG',
#   'Weather Description': 'few clouds'},
#  {'City': 'Belo Oriente',
#   'Lat': -19.22,
#   'Lng': -42.4836,
#   'Max Temp': 80.35,
#   'Humidity': 58,
#   'Cloudiness': 85,
#   'Wind Speed': 5.12,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zulpich',
#   'Lat': 50.7,
#   'Lng': 6.65,
#   'Max Temp': 55.18,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'DE',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Zdvinsk',
#   'Lat': 54.7021,
#   'Lng': 78.661,
#   'Max Temp': 40.75,
#   'Humidity': 82,
#   'Cloudiness': 65,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 60.21,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hagere Hiywet',
#   'Lat': 8.9833,
#   'Lng': 37.85,
#   'Max Temp': 54.46,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 5.46,
#   'Country': 'ET',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lingao',
#   'Lat': 19.9103,
#   'Lng': 109.6859,
#   'Max Temp': 76.06,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.19,
#   'Country': 'CN',
#   'Weather Description': 'light rain'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 58.19,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 14.23,
#   'Country': 'JP',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 30.34,
#   'Humidity': 38,
#   'Cloudiness': 3,
#   'Wind Speed': 3.29,
#   'Country': 'GL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.64,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.48,
#   'Country': 'IN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Charleville-Mezieres',
#   'Lat': 49.7667,
#   'Lng': 4.7167,
#   'Max Temp': 56.88,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 4.97,
#   'Country': 'FR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Suluq',
#   'Lat': 31.6682,
#   'Lng': 20.2521,
#   'Max Temp': 72.23,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 12.1,
#   'Country': 'LY',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poykovskiy',
#   'Lat': 61.2333,
#   'Lng': 73.3333,
#   'Max Temp': 43.09,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Merauke',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 78.08,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 76.15,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Durres',
#   'Lat': 41.3231,
#   'Lng': 19.4414,
#   'Max Temp': 57.38,
#   'Humidity': 68,
#   'Cloudiness': 3,
#   'Wind Speed': 7.34,
#   'Country': 'AL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.2,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Country': 'PT',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 66.83,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 6.46,
#   'Country': 'ES',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 79.14,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'LK',
#   'Weather Description': 'clear sky'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 68.11,
#   'Humidity': 23,
#   'Cloudiness': 6,
#   'Wind Speed': 8.34,
#   'Country': 'SA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alacranes',
#   'Lat': 22.7675,
#   'Lng': -81.5675,
#   'Max Temp': 83.39,
#   'Humidity': 72,
#   'Cloudiness': 50,
#   'Wind Speed': 7.11,
#   'Country': 'CU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Merrill',
#   'Lat': 45.1805,
#   'Lng': -89.6835,
#   'Max Temp': 69.98,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 82.9,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Skegness',
#   'Lat': 53.1436,
#   'Lng': 0.3363,
#   'Max Temp': 59.34,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.72,
#   'Country': 'GB',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 88.97,
#   'Humidity': 11,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'MR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 57.97,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 5.86,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Zonguldak',
#   'Lat': 41.25,
#   'Lng': 31.8333,
#   'Max Temp': 48.58,
#   'Humidity': 97,
#   'Cloudiness': 82,
#   'Wind Speed': 1.5,
#   'Country': 'TR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kirkuk',
#   'Lat': 35.4681,
#   'Lng': 44.3922,
#   'Max Temp': 71.89,
#   'Humidity': 43,
#   'Cloudiness': 6,
#   'Wind Speed': 4.88,
#   'Country': 'IQ',
#   'Weather Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 47.7,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Da Nang',
#   'Lat': 16.0678,
#   'Lng': 108.2208,
#   'Max Temp': 76.98,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'VN',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nanticoke',
#   'Lat': 41.2054,
#   'Lng': -76.0049,
#   'Max Temp': 57.25,
#   'Humidity': 65,
#   'Cloudiness': 94,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bhiwani',
#   'Lat': 28.7833,
#   'Lng': 76.1333,
#   'Max Temp': 70.38,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.97,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Statesboro',
#   'Lat': 32.4488,
#   'Lng': -81.7832,
#   'Max Temp': 75.34,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Owando',
#   'Lat': -0.4819,
#   'Lng': 15.8999,
#   'Max Temp': 75.99,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 3.27,
#   'Country': 'CG',
#   'Weather Description': 'light rain'},
#  {'City': 'Sao Paulo De Olivenca',
#   'Lat': -3.3783,
#   'Lng': -68.8725,
#   'Max Temp': 87.39,
#   'Humidity': 60,
#   'Cloudiness': 96,
#   'Wind Speed': 1.23,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guarapari',
#   'Lat': -20.6667,
#   'Lng': -40.4975,
#   'Max Temp': 75.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'BR',
#   'Weather Description': 'light rain'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 47.37,
#   'Humidity': 87,
#   'Cloudiness': 31,
#   'Wind Speed': 7.07,
#   'Country': 'AU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Gold Coast',
#   'Lat': -28,
#   'Lng': 153.4333,
#   'Max Temp': 59.38,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Katete',
#   'Lat': -0.7818,
#   'Lng': 29.7544,
#   'Max Temp': 63.75,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.43,
#   'Country': 'UG',
#   'Weather Description': 'light rain'},
#  {'City': 'Douentza',
#   'Lat': 14.9951,
#   'Lng': -2.9517,
#   'Max Temp': 93.51,
#   'Humidity': 24,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'ML',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 32.29,
#   'Humidity': 38,
#   'Cloudiness': 2,
#   'Wind Speed': 7.38,
#   'Country': 'GL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kondagaon',
#   'Lat': 19.6,
#   'Lng': 81.6667,
#   'Max Temp': 71.28,
#   'Humidity': 97,
#   'Cloudiness': 92,
#   'Wind Speed': 4.36,
#   'Country': 'IN',
#   'Weather Description': 'light rain'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 71.04,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 50.88,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 49.17,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Country': 'NZ',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 33.8,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 26.11,
#   'Country': 'NO',
#   'Weather Description': 'light rain'},
#  {'City': 'Sterling',
#   'Lat': 39.0062,
#   'Lng': -77.4286,
#   'Max Temp': 70.48,
#   'Humidity': 43,
# ...
#   'Cloudiness': 90,
#   'Wind Speed': 10.07,
#   'Country': 'SO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kerman',
#   'Lat': 30.2832,
#   'Lng': 57.0788,
#   'Max Temp': 66.06,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'IR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Poyarkovo',
#   'Lat': 49.6,
#   'Lng': 128.6833,
#   'Max Temp': 21.45,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tondano',
#   'Lat': 1.3038,
#   'Lng': 124.9112,
#   'Max Temp': 69.89,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 1.61,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Henderson',
#   'Lat': 36.0397,
#   'Lng': -114.9819,
#   'Max Temp': 68.11,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 24.16,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Neryungri',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': 18.86,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Nileshwar',
#   'Lat': 12.25,
#   'Lng': 75.1,
#   'Max Temp': 77.61,
#   'Humidity': 86,
#   'Cloudiness': 77,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bukachacha',
#   'Lat': 52.9833,
#   'Lng': 116.9167,
#   'Max Temp': 19.99,
#   'Humidity': 91,
#   'Cloudiness': 83,
#   'Wind Speed': 1.63,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Magna',
#   'Lat': 40.7091,
#   'Lng': -112.1016,
#   'Max Temp': 64.8,
#   'Humidity': 39,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 46.76,
#   'Humidity': 35,
#   'Cloudiness': 6,
#   'Wind Speed': 10.02,
#   'Country': 'KZ',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cadiz',
#   'Lat': 36.5,
#   'Lng': -5.75,
#   'Max Temp': 73.13,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 10.45,
#   'Country': 'ES',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -6.38,
#   'Humidity': 97,
#   'Cloudiness': 50,
#   'Wind Speed': 1.61,
#   'Country': 'RU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Auburn',
#   'Lat': 47.3073,
#   'Lng': -122.2284,
#   'Max Temp': 55.8,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Angelo',
#   'Lat': 31.4638,
#   'Lng': -100.437,
#   'Max Temp': 79.65,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Morant Bay',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 89.22,
#   'Humidity': 74,
#   'Cloudiness': 60,
#   'Wind Speed': 9.1,
#   'Country': 'JM',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 51.06,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'CA',
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Uarini',
#   'Lat': -2.99,
#   'Lng': -65.1083,
#   'Max Temp': 93.15,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Santa Cruz De La Palma',
#   'Lat': 28.6835,
#   'Lng': -17.7642,
#   'Max Temp': 82.54,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ban Chang',
#   'Lat': 12.7254,
#   'Lng': 101.0553,
#   'Max Temp': 79.48,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'TH',
#   'Weather Description': 'few clouds'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 74.48,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'JP',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hollins',
#   'Lat': 37.3413,
#   'Lng': -79.9431,
#   'Max Temp': 71.53,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Baryatino',
#   'Lat': 54.3121,
#   'Lng': 34.521,
#   'Max Temp': 35.83,
#   'Humidity': 84,
#   'Cloudiness': 12,
#   'Wind Speed': 7.72,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bialogard',
#   'Lat': 54.007,
#   'Lng': 15.9875,
#   'Max Temp': 49.12,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'PL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Russell',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 74.91,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mudanjiang',
#   'Lat': 44.5833,
#   'Lng': 129.6,
#   'Max Temp': 24.49,
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 1.99,
#   'Country': 'CN',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 71.71,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'VU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 58.71,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dawlatabad',
#   'Lat': 36.4141,
#   'Lng': 64.9053,
#   'Max Temp': 57.6,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'AF',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 71.71,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 7.83,
#   'Country': 'BR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kathu',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 86.7,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.06,
#   'Country': 'TH',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Ocampo',
#   'Lat': 21.65,
#   'Lng': -101.5,
#   'Max Temp': 72.28,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 60.37,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kumo',
#   'Lat': 10.0447,
#   'Lng': 11.2122,
#   'Max Temp': 79.95,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'NG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 72.03,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 81.34,
#   'Humidity': 77,
#   'Cloudiness': 55,
#   'Wind Speed': 3.87,
#   'Country': 'SB',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Svarstad',
#   'Lat': 59.399,
#   'Lng': 9.9698,
#   'Max Temp': 40.82,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 1.12,
#   'Country': 'NO',
#   'Weather Description': 'light rain'},
#  {'City': 'Indramayu',
#   'Lat': -6.3264,
#   'Lng': 108.32,
#   'Max Temp': 80.15,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 4.41,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Liwale',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp': 73.78,
#   'Humidity': 68,
#   'Cloudiness': 77,
#   'Wind Speed': 8.23,
#   'Country': 'TZ',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 63.59,
#   'Humidity': 63,
#   'Cloudiness': 22,
#   'Wind Speed': 5.23,
#   'Country': 'CL',
#   'Weather Description': 'few clouds'},
#  {'City': 'Qena',
#   'Lat': 26.1615,
#   'Lng': 32.7183,
#   'Max Temp': 82.51,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 11.32,
#   'Country': 'EG',
#   'Weather Description': 'clear sky'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 26.71,
#   'Humidity': 77,
#   'Cloudiness': 58,
#   'Wind Speed': 20.04,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nanchang',
#   'Lat': 28.6833,
#   'Lng': 115.8833,
#   'Max Temp': 58.32,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.19,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 79.93,
#   'Humidity': 78,
#   'Cloudiness': 57,
#   'Wind Speed': 18.7,
#   'Country': 'PF',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Codajas',
#   'Lat': -3.8367,
#   'Lng': -62.0569,
#   'Max Temp': 90.7,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 1.28,
#   'Country': 'BR',
#   'Weather Description': 'light rain'},
#  {'City': 'Denpasar',
#   'Lat': -8.65,
#   'Lng': 115.2167,
#   'Max Temp': 80.26,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'ID',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Maroantsetra',
#   'Lat': -15.4333,
#   'Lng': 49.7333,
#   'Max Temp': 69.85,
#   'Humidity': 83,
#   'Cloudiness': 13,
#   'Wind Speed': 2.24,
#   'Country': 'MG',
#   'Weather Description': 'few clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 42.58,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sao Miguel Do Araguaia',
#   'Lat': -13.275,
#   'Lng': -50.1628,
#   'Max Temp': 82,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cabra',
#   'Lat': 37.4725,
#   'Lng': -4.4421,
#   'Max Temp': 76.44,
#   'Humidity': 51,
#   'Cloudiness': 99,
#   'Wind Speed': 3.51,
#   'Country': 'ES',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yangcun',
#   'Lat': 39.3639,
#   'Lng': 117.0603,
#   'Max Temp': 48.18,
#   'Humidity': 57,
#   'Cloudiness': 66,
#   'Wind Speed': 9.55,
#   'Country': 'CN',
#   'Weather Description': 'light rain'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 67.69,
#   'Humidity': 75,
#   'Cloudiness': 50,
#   'Wind Speed': 10.18,
#   'Country': 'PE',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Griffith',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 74.08,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 75.04,
#   'Humidity': 23,
#   'Cloudiness': 94,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Santiago Del Estero',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp': 78.8,
#   'Humidity': 18,
#   'Cloudiness': 8,
#   'Wind Speed': 6.4,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 77.72,
#   'Humidity': 59,
#   'Cloudiness': 11,
#   'Wind Speed': 14.47,
#   'Country': 'BS',
#   'Weather Description': 'few clouds'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 17.73,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 11.54,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Baturaja',
#   'Lat': -4.1333,
#   'Lng': 104.1667,
#   'Max Temp': 73,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Eirunepe',
#   'Lat': -6.6603,
#   'Lng': -69.8736,
#   'Max Temp': 80.6,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Marystown',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 49.86,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Derzhavinsk',
#   'Lat': 51.1,
#   'Lng': 66.3167,
#   'Max Temp': 49.21,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Country': 'KZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Amarante Do Maranhao',
#   'Lat': -5.5667,
#   'Lng': -46.7422,
#   'Max Temp': 79.02,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lutz',
#   'Lat': 28.1511,
#   'Lng': -82.4615,
#   'Max Temp': 85.01,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Plouzane',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 64.72,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'FR',
#   'Weather Description': 'mist'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 80.17,
#   'Humidity': 26,
#   'Cloudiness': 3,
#   'Wind Speed': 6.96,
#   'Country': 'SA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 45.21,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 79.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.53,
#   'Country': 'PG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'El Reno',
#   'Lat': 35.5323,
#   'Lng': -97.955,
#   'Max Temp': 74.19,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 23.02,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Santa Isabel',
#   'Lat': -23.3156,
#   'Lng': -46.2214,
#   'Max Temp': 64.65,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tamandare',
#   'Lat': -8.7597,
#   'Lng': -35.1047,
#   'Max Temp': 81.18,
#   'Humidity': 68,
#   'Cloudiness': 97,
#   'Wind Speed': 8.66,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 88.59,
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 10.85,
#   'Country': 'CV',
#   'Weather Description': 'clear sky'},
#  {'City': 'Moscow',
#   'Lat': 55.7522,
#   'Lng': 37.6156,
#   'Max Temp': 38.75,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 10.11,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Las Vegas',
#   'Lat': 36.175,
#   'Lng': -115.1372,
#   'Max Temp': 67.53,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Shatrovo',
#   'Lat': 56.5167,
#   'Lng': 64.6333,
#   'Max Temp': 46.06,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 54.23,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 13.91,
#   'Country': 'NZ',
#   'Weather Description': 'clear sky'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 78.85,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 8.25,
#   'Country': 'AO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Leu',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp': 72.43,
#   'Humidity': 95,
#   'Cloudiness': 2,
#   'Wind Speed': 7.76,
#   'Country': 'RE',
#   'Weather Description': 'clear sky'},
#  {'City': 'Odesskoye',
#   'Lat': 54.2111,
#   'Lng': 72.9651,
#   'Max Temp': 47.82,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ndele',
#   'Lat': 8.4109,
#   'Lng': 20.6473,
#   'Max Temp': 73.26,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 1.83,
#   'Country': 'CF',
#   'Weather Description': 'light rain'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -16.51,
#   'Humidity': 98,
#   'Cloudiness': 37,
#   'Wind Speed': 4.34,
#   'Country': 'RU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Santa Lucia',
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp': 68.76,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Luderitz -26.6481   15.1594     74.48        24         100
# 1         Wagar  16.1525   36.2032     89.24        25           0
# 2       Rikitea -23.1203 -134.9692     75.13        71           6
# 3     Cape Town -33.9258   18.4232     60.12        64           0
# 4       Ushuaia -54.8000  -68.3000     55.02        57          40
# 5  Punta Arenas -53.1500  -70.9167     55.51        41          20
# 6   Port Alfred -33.5906   26.8910     57.43        65           0
# 7      Khatanga  71.9667  102.5000     29.89        98         100
# 8        Razole  16.4833   81.8333     78.57        90         100
# 9     Kanganpur  30.7663   74.1231     72.88        67           0
#
#    Wind Speed Country Weather Description
# 0       17.05      NA     overcast clouds
# 1       12.33      SD           clear sky
# 2       18.39      PF           clear sky
# 3        5.01      ZA           clear sky
# 4       31.07      AR    scattered clouds
# 5       29.93      CL          few clouds
# 6        3.87      ZA           clear sky
# 7        9.37      RU          light snow
# 8        2.28      IN     overcast clouds
# 9        5.50      PK           clear sky

# %%
new_column_order = ["City" ,"Country" , "Lat" ,"Lng" , "Max Temp","Humidity","Cloudiness" ,"Wind Speed","Weather Description"]
df = city_data_df[new_column_order] 
df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Luderitz      NA -26.6481   15.1594     74.48        24         100
# 1          Wagar      SD  16.1525   36.2032     89.24        25           0
# 2        Rikitea      PF -23.1203 -134.9692     75.13        71           6
# 3      Cape Town      ZA -33.9258   18.4232     60.12        64           0
# 4        Ushuaia      AR -54.8000  -68.3000     55.02        57          40
# ..           ...     ...      ...       ...       ...       ...         ...
# 667    Saint-Leu      RE -21.1500   55.2833     72.43        95           2
# 668    Odesskoye      RU  54.2111   72.9651     47.82        56         100
# 669        Ndele      CF   8.4109   20.6473     73.26        92          40
# 670  Deputatskiy      RU  69.3000  139.9000    -16.51        98          37
# 671  Santa Lucia      ES  27.9117  -15.5407     68.76        76           0
#
#      Wind Speed Weather Description
# 0         17.05     overcast clouds
# 1         12.33           clear sky
# 2         18.39           clear sky
# 3          5.01           clear sky
# 4         31.07    scattered clouds
# ..          ...                 ...
# 667        7.76           clear sky
# 668        6.89     overcast clouds
# 669        1.83          light rain
# 670        4.34    scattered clouds
# 671       14.97           clear sky
#
# [672 rows x 9 columns]

# %%
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file = "C:/Users/abaze/OneDrive/Desktop/database/Classwork/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
